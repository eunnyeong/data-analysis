# %%
import pandas as pd

# %%
# 화면에 출력하는 데이터 프레임의 최대 row 수를 500으로 설정
pd.set_option('display.max_rows', 500)

# 화면에 출력하는 데이터 프레임의 최대 column 수를 500으로 설정
pd.set_option('display.max_columns', 500)

# %%
# python에서 DB를 다루는 library인 sqlite3와 데이터를 다루는 library인 padas를 import
import sqlite3

# %%
connection = sqlite3.connect("./zigzag/zigzag_DB.db")
connection

# %%
query = "SELECT * FROM 'order'"

order = pd.read_sql(query, connection)

order.head()
# Out:
#                  timestamp                           user_id  goods_id  \
# 0  2018-06-11 00:00:43.032  bvu0aLTqiFDoU-963xnr5nzQWTNLUMjx      1414
# 1  2018-06-11 00:02:33.763  smDmRnykg61KajpxXKzQ0oNkrh2nuSBj      1351
# 2  2018-06-11 00:04:06.364  EyGjKYtSqZgqJ1ddKCtH5XwGirTyOH2P       646
# 3  2018-06-11 00:04:17.258  KQBGi33Zxh5Dgu0WEkOkjN0YqTT_wxC3      5901
# 4  2018-06-11 00:05:26.010  lq1Je3voA3a0MouSFba3629lKCvweI24      5572
#
#    shop_id  price
# 0       38  45000
# 1       12   9500
# 2       14  22000
# 3       46  29800
# 4       89  29000

# %%
table = pd.pivot_table(order,
                       index = "shop_id",
                       values = "price", 
                       aggfunc = 'sum')

table = table.sort_values(by = "price", ascending = False)

table.head(10)
# Out:
#            price
# shop_id
# 22       1365200
# 14        872000
# 63        710700
# 32        707900
# 126       669400
# 6         655900
# 11        653000
# 60        558300
# 19        518400
# 12        446900

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.rc('font', family = "NanumGothic")

# %%
table = pd.pivot_table(order, 
                       index = "shop_id", 
                       values = "price", 
                       aggfunc = ['sum', 'count'])

table.columns = ['sum', 'count']

table = table.sort_values(by = 'sum', ascending = False)

top_table = table.head(10)

top_table
# Out:
#              sum  count
# shop_id
# 22       1365200     99
# 14        872000     30
# 63        710700     27
# 32        707900     37
# 126       669400     39
# 6         655900     24
# 11        653000     19
# 60        558300     23
# 19        518400     19
# 12        446900     42

# %%
# 피벗테이블 시각화

# sns.barplot(data = top_table, x = "shop_id", y = "sum") #인덱스는 컬럼이 아니기 때문에 오류
sns.barplot(data = top_table, 
            x = top_table.index, 
            y = "sum", 
            order = top_table.index)

# %%
import matplotlib as mpl

sns.set_style('whitegrid')

mpl.rc('font', family='Malgun Gothic')
mpl.rc('axes', unicode_minus=False)

from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

# %%
order['timestamp'] = pd.to_datetime(order['timestamp'])

order.dtypes
# Out:
# timestamp    datetime64[ns]
# user_id              object
# goods_id              int64
# shop_id               int64
# price                 int64
# dtype: object

# %%
fig, ax1 = plt.subplots(ncols=1, nrows=1)
fig.set_size_inches([14, 3])

sns.lineplot(data = order, x = 'timestamp', y = 'price', ax = ax1)
# Out:
# c:\users\eunnyoung\appdata\local\programs\python\python36\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
# order 테이블에 로그의 발생 시간을 나타내는 hour 칼럼을 추가한 뒤, pivot_table을 이용하여 시간대별 매출 구하기

order['hour'] = order['timestamp'].dt.hour

table = pd.pivot_table(order, 
                       index = 'hour', 
                       values = 'price', 
                       aggfunc = 'sum')

table.head()
# Out:
#         price
# hour
# 0     1479210
# 1      990300
# 2      787830
# 3      467650
# 4      304800

# %%
fig, ax1 = plt.subplots(ncols=1, nrows=1)
fig.set_size_inches([14, 4])

sns.lineplot(data = table, x = table.index, y = 'price', ax = ax1)

# %%
fig, ax1 = plt.subplots(ncols=1, nrows=1)
fig.set_size_inches([14, 4])

sns.pointplot(data = table, x = table.index, y = 'price', ax = ax1)

# %%
user = pd.read_sql("SELECT * FROM 'user'", connection)

user.head()
# Out:
#                             user_id   os  age
# 0  --PYPMX8QWg0ioT5zfORmU-S5Lln0lot  And   41
# 1  -16-xXbeDcvkZJtTpRwMi57Yo2ZQpORv  iOS   31
# 2  -1de9sT-MLwVVvnC0ncCLnqEqpSi3XSN  iOS   16
# 3  -3A3L2jnM55B_Q1bRXMjZ6sPnINIj-Y1  And   41
# 4  -3bhcSgPOIdQAPkPNcchxvECGqGQQ78k  And   42

# %%
order_user = pd.merge(order, user, on = 'user_id')

order_user.head()
# Out:
#                 timestamp                           user_id  goods_id  \
# 0 2018-06-11 00:00:43.032  bvu0aLTqiFDoU-963xnr5nzQWTNLUMjx      1414
# 1 2018-06-11 00:02:33.763  smDmRnykg61KajpxXKzQ0oNkrh2nuSBj      1351
# 2 2018-06-11 00:04:06.364  EyGjKYtSqZgqJ1ddKCtH5XwGirTyOH2P       646
# 3 2018-06-11 00:04:17.258  KQBGi33Zxh5Dgu0WEkOkjN0YqTT_wxC3      5901
# 4 2018-06-11 00:05:26.010  lq1Je3voA3a0MouSFba3629lKCvweI24      5572
#
#    shop_id  price  hour   os  age
# 0       38  45000     0  iOS   39
# 1       12   9500     0  And   17
# 2       14  22000     0  And   -1
# 3       46  29800     0  And   34
# 4       89  29000     0  And   17

# %%
top10_order_user = order_user[order_user['age'] != -1]

top10_order_user.head()
# Out:
#                 timestamp                           user_id  goods_id  \
# 0 2018-06-11 00:00:43.032  bvu0aLTqiFDoU-963xnr5nzQWTNLUMjx      1414
# 1 2018-06-11 00:02:33.763  smDmRnykg61KajpxXKzQ0oNkrh2nuSBj      1351
# 3 2018-06-11 00:04:17.258  KQBGi33Zxh5Dgu0WEkOkjN0YqTT_wxC3      5901
# 4 2018-06-11 00:05:26.010  lq1Je3voA3a0MouSFba3629lKCvweI24      5572
# 5 2018-06-11 00:05:35.182  GM0-EsJPHjkpteIpAQIwaCdUjU81lhW1        55
#
#    shop_id  price  hour   os  age
# 0       38  45000     0  iOS   39
# 1       12   9500     0  And   17
# 3       46  29800     0  And   34
# 4       89  29000     0  And   17
# 5       22  11200     0  iOS   21

# %%
top10_shop_id = order_user.groupby('shop_id').sum()

top10_shop_id = top10_shop_id.sort_values(by = 'price', ascending = False)[0:10]

top10_order_user = top10_order_user[top10_order_user['shop_id'].isin(top10_shop_id.index)]

top10_order_user.head()
# Out:
#                 timestamp                           user_id  goods_id  \
# 1 2018-06-11 00:02:33.763  smDmRnykg61KajpxXKzQ0oNkrh2nuSBj      1351
# 5 2018-06-11 00:05:35.182  GM0-EsJPHjkpteIpAQIwaCdUjU81lhW1        55
# 6 2018-06-11 00:06:14.314  lgvWxrv7r5RGklXSJqM2x6NUBZ5H-RQZ      2451
# 7 2018-06-11 00:08:39.716  LZZ0ktGq6hW685TFAQfcGNhsKVUEceHl      4278
# 9 2018-06-11 00:11:30.954  Evz6xmsye1BP7i33rr_RAjwBRZ_AOsTZ       686
#
#    shop_id  price  hour   os  age
# 1       12   9500     0  And   17
# 5       22  11200     0  iOS   21
# 6       22  19800     0  iOS   22
# 7       60  23500     0  iOS   24
# 9       22  12900     0  And   27

# %%
plt.figure(figsize=[6,4])

sns.boxplot(x = 'shop_id', y = 'age', data = top10_order_user)

# %%
def make_generation(age):
    if age == -1:
        return '미입력'
    elif age // 10 >= 4:
        return "30대 후반"
    elif age // 10 == 1:
        return "10대"
    elif age % 10 < 3:
        return str(age // 10 * 10) + f"대 초반"
    elif age % 10 <= 6:
        return str(age // 10 * 10) + f"대 중반"
    else:
        return str(age // 10 * 10) + f"대 후반"

    
print(make_generation(10))
print(make_generation(23))
print(make_generation(29))
print(make_generation(32))
print(make_generation(35))
print(make_generation(40))
# Out:
# 10대
# 20대 중반
# 20대 후반
# 30대 초반
# 30대 중반
# 30대 후반

# %%
# 1. 실제 나이를 바탕으로 user 테이블에 연령대 칼럼을 만들기

user['연령대'] = user['age'].apply(make_generation)

user.head()
# Out:
#                             user_id   os  age     연령대
# 0  --PYPMX8QWg0ioT5zfORmU-S5Lln0lot  And   41  30대 후반
# 1  -16-xXbeDcvkZJtTpRwMi57Yo2ZQpORv  iOS   31  30대 초반
# 2  -1de9sT-MLwVVvnC0ncCLnqEqpSi3XSN  iOS   16     10대
# 3  -3A3L2jnM55B_Q1bRXMjZ6sPnINIj-Y1  And   41  30대 후반
# 4  -3bhcSgPOIdQAPkPNcchxvECGqGQQ78k  And   42  30대 후반

# %%
# shop 테이블을 불러와 user, order 테이블과 병합하기

shop = pd.read_sql("SELECT * FROM 'shop'", connection)
shop.head()

order_user = pd.merge(order, user, on = 'user_id')
print(order_user.shape)

order_user_shop = pd.merge(order_user, shop, on = 'shop_id')
print(order_user_shop.shape)

order_user_shop.head()
# Out:
# (867, 9)
# (867, 13)
#                 timestamp                           user_id  goods_id  \
# 0 2018-06-11 00:00:43.032  bvu0aLTqiFDoU-963xnr5nzQWTNLUMjx      1414
# 1 2018-06-11 07:33:39.823  ni3NQK35j-YaSxli-C_Sz7ZmQqOwMljL      2278
# 2 2018-06-11 12:56:27.867  MnvhmV0tA89bN9TLXgRTbLza689bTkT9      5513
# 3 2018-06-11 22:57:11.582  3Vo9NP0qU_176pgbqk6Cu-CY7kpJ2-WB      7026
# 4 2018-06-11 00:02:33.763  smDmRnykg61KajpxXKzQ0oNkrh2nuSBj      1351
#
#    shop_id  price  hour   os  age_x     연령대    name category  \
# 0       38  45000     0  iOS     39  30대 후반   Mabel       의류
# 1       38  37000     7  And     32  30대 초반   Mabel       의류
# 2       38  31000    12  And     37  30대 후반   Mabel       의류
# 3       38  17100    22  iOS     34  30대 중반   Mabel       의류
# 4       12   9500     0  And     17     10대  Rachel       의류
#
#                   age_y      style
# 0  20대 후반/30대 초반/30대 중반   모던시크/페미닌
# 1  20대 후반/30대 초반/30대 중반   모던시크/페미닌
# 2  20대 후반/30대 초반/30대 중반   모던시크/페미닌
# ...

# %%
def check_generation(row):
    if row['category'] == '의류' and row['연령대'] == '미입력':
        return True
    else:
        return row['연령대'] in str(row['age_y'])

# %%
# 3. 쇼핑몰의 타겟 연령대와 해당 쇼핑몰에서의 결제를 한 고객의 연령대를 비교하기
# 병합한 테이블을 이용하여 '거래연령 일치여부' 칼럼을 아래의 칼럼을 이용 
# 각 열이 아닌 각 행에 함수를 적용할 때는 apply(function, axis=1)을 이용

order_user_shop['거래연령 일치여부'] = order_user_shop.apply(check_generation, axis = 1)

table = pd.pivot_table(order_user_shop, 
                       values = '거래연령 일치여부', 
                       index = 'shop_id', 
                       aggfunc = ['mean', 'count'])

table.head()
# Out:
#              mean     count
#         거래연령 일치여부 거래연령 일치여부
# shop_id
# 1        0.666667         3
# 2        0.937500        16
# 3        0.400000         5
# 4        1.000000         1
# 5        0.000000         1

# %%
# table[table.index.isin(top10_index)]

table = table[table.index.isin(top10_shop_id.index)]

table
# Out:
#              mean     count
#         거래연령 일치여부 거래연령 일치여부
# shop_id
# 6        0.750000        24
# 11       0.684211        19
# 12       0.857143        42
# 14       0.566667        30
# 19       0.789474        19
# 22       0.929293        99
# 32       0.540541        37
# 60       0.695652        23
# 63       0.000000        27
# 126      0.000000        39

# %%
style_list = ['페미닌', '모던시크', '심플베이직', '러블리', '유니크', '미시스타일', '캠퍼스룩', '빈티지', '섹시글램', '스쿨룩', '로맨틱', '오피스룩',
              '럭셔리', '헐리웃스타일', '심플시크', '키치', '펑키', '큐티', '볼드&에스닉' ]

# %%
def clean_style(style):
    print('모던시크' in style.split('/'))
    
shop_copy = shop.loc[0:1].copy()
shop_copy['style'].apply(clean_style)
shop_copy.head()
# Out:
# True
# False
#    shop_id  name category                   age      style
# 0        1  Edna       의류  20대 중반/20대 후반/30대 초반   모던시크/러블리
# 1        2   Pam       의류  20대 중반/20대 후반/30대 초반  러블리/심플베이직

# %%
# for compare in style_list:
#     print(compare)

def clean_style(style, compare):
    return compare in style.split('/')
    
shop_copy = shop.loc[0:1].copy()

for compare in ['모던시크', '러블리']:
    shop_copy[compare] = shop_copy['style'].apply(lambda style : clean_style(style, compare))
    
shop_copy.head()
# Out:
#    shop_id  name category                   age      style   모던시크   러블리
# 0        1  Edna       의류  20대 중반/20대 후반/30대 초반   모던시크/러블리   True  True
# 1        2   Pam       의류  20대 중반/20대 후반/30대 초반  러블리/심플베이직  False  True

# %%
def clean_style(style, compare):
    if pd.isnull(style):
        return False
    else: 
        return compare in style.split('/')
    
shop_copy = shop.copy()

for compare in style_list:
    shop_copy[compare] = shop_copy['style'].apply(lambda style : clean_style(style, compare))
    
shop_copy.head()
# Out:
#    shop_id     name category                   age         style    페미닌  \
# 0        1     Edna       의류  20대 중반/20대 후반/30대 초반      모던시크/러블리  False
# 1        2      Pam       의류  20대 중반/20대 후반/30대 초반     러블리/심플베이직  False
# 2        3  Carolyn       의류  20대 중반/20대 후반/30대 초반    모던시크/심플베이직  False
# 3        4     Joan       의류         30대 초반/30대 중반     미시스타일/유니크  False
# 4        5  Florene       의류  20대 중반/20대 후반/30대 초반  심플베이직/헐리웃스타일  False
#
#     모던시크  심플베이직    러블리    유니크  미시스타일   캠퍼스룩    빈티지   섹시글램    스쿨룩    로맨틱  \
# 0   True  False   True  False  False  False  False  False  False  False
# 1  False   True   True  False  False  False  False  False  False  False
# 2   True   True  False  False  False  False  False  False  False  False
# 3  False  False  False   True   True  False  False  False  False  False
# 4  False   True  False  False  False  False  False  False  False  False
#
#     오피스룩    럭셔리  헐리웃스타일   심플시크     키치     펑키     큐티  볼드&에스닉
# ...

# %%
shop_copy = shop_copy.set_index('shop_id')

shop_copy.head()
# Out:
#             name category                   age         style    페미닌   모던시크  \
# shop_id
# 1           Edna       의류  20대 중반/20대 후반/30대 초반      모던시크/러블리  False   True
# 2            Pam       의류  20대 중반/20대 후반/30대 초반     러블리/심플베이직  False  False
# 3        Carolyn       의류  20대 중반/20대 후반/30대 초반    모던시크/심플베이직  False   True
# 4           Joan       의류         30대 초반/30대 중반     미시스타일/유니크  False  False
# 5        Florene       의류  20대 중반/20대 후반/30대 초반  심플베이직/헐리웃스타일  False  False
#
#          심플베이직    러블리    유니크  미시스타일   캠퍼스룩    빈티지   섹시글램    스쿨룩    로맨틱   오피스룩  \
# shop_id
# 1        False   True  False  False  False  False  False  False  False  False
# 2         True   True  False  False  False  False  False  False  False  False
# 3         True  False  False  False  False  False  False  False  False  False
# 4        False  False   True   True  False  False  False  False  False  False
# 5         True  False  False  False  False  False  False  False  False  False
#
# ...
